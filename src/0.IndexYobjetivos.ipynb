# %% [markdown]
# OBJETIVOS DEL PROYECTO:
#
# 1: ETIQUETACIÓN DEL USUARIO VIA APP STREAMLIT (SOLO PERSONAS NACIDAS EN EUROPA CON O SIN PADRES EXTRANJEROS)
#      A PERFILES PREDEFINIDOS OBTENIDOS GRACIAS A DATOS ECONOMICOS
#      (INFLACION, PIB PER CAPITA, SUELDO BRUTO MENSUAL MEDIO, DE LA EUROZONA.),
#      Y DATOS CATEGORICOS, SOCIALES Y PERSONALES, OBTENIDOS GRACIAS A LOS DATOS DE ENCUESTAS DEL ORGANISMO ESS.
#
# 2: PREDECIR VALORES Y ASPECTOS SOCIOPOLÍTICOS DEL USUARIO A TRAVES DE POCA INFORMACION OBTENIDA EN UN QUERY ANSWER DE STREAMLIT.
#
# 3: ENVIO PERSONALIZADO AL USUARIO DE STREAMLIT, A TRAVES DE EMAIL, DE INFORMACION Y PUBLICIDAD ESPECIALIZADA A SUS GUSTOS Y NECESIDADES.
#
# 4: MOSTRAR LA TENDENCIA A AÑO VISTA DEL PERFIL POLÍTICO, SOCIAL Y PERSONAL DEL USUARIO.

# %% [markdown]
# ÍNDICE:
#
# 1. DATA RESEARCH: EN ESTE DOCUMENTO DE EXPLORACION, CONSIGO OBTENER UNA GRAN CANTIDAD DE DATOS SOCIOECONOMICOS DEL PORTAL ESS, SELECCIONANDO VARIABLES,
#     SEPARADAS POR 4 GRANDES BLOQUES, CONSIGO AJUSTAR EL DATASET CON 10MIL FILAS CON LAS VARIABLES MAS RELEVANTES E INTERESANTES PARA DISEÑAR UN MODELO
#     DE CLUSTERIZACION Y/O PREDICCION DE VARIABLES TARGET, AL MENOS UNA TARGET POR CADA UNO DE LOS CUATROS BLOQUES. SE ALMACENAN EN SQL(..\ProyectoFinal\data\processed\Dataset9k.db)
#     PARA TRABAJAR POSTERIORMENTE EN EL EDA.
#
# 2. DATA RESEARCH: EN ESTE DOCUMENTO DE EXPLORACION, REALIZAMOS WEBSCRAPPING EN PAGINAS ESPECIALIZADAS DE ECONOMIA, WEB DEL BANCO MUNDIAL Y WEB DEL IDEALISTA,
#     MEDIANTE WEBSCRAPPING(Selenium e Instant Data Scrapper) OBTENGO TABLAS ECNÓMICAS (inflación, PIB per Capita y Sueldo Bruto Mensual Medio, de la Zona Euro)
#     Y LAS ALMACENO EN SQL(..\ProyectoFinal\data\processed\Dataset9k.db).
#
# 3. EDA: EN ESTE DOCUMENTO DE EXPLORACION REALIZAREMOS EL EDA Y EL FEATURE ENGINEERING, PARA GUARDAR NUESTROS MODELOS,
#     Y UTILIZARLOS EN STREAMLIT POSTERIORMENTE.
#
# 4. STREAMLIT APP: DISEÑAREMOS UNA APP SENCILLA CON INTERFAZ WEB GRACIAS A STREAMLIT PARA INTRODUCIR DATOS DEL USUARIO Y PROCESARLOS,
#     DAREMOS AL USUARIO UNA INFORMACION Y SERVICIO ÚTIL.
